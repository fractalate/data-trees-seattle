# %% [markdown]
# # Exploration of Trees
#
# Let's learn about specific trees!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import json
from typing import Tuple, TypedDict

from sdot import SDOT
from wcvp import WCVP

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %%
sdot = SDOT('SDOT_Trees_CDL_20241119.csv')
wcvp = WCVP('wcvp_taxon.csv', 'wcvp_distribution.csv')

dfsdot = sdot.dfsdot
dftaxon, dfdist = wcvp.dftaxon, wcvp.dfdist

# %%
print(dftaxon[
      (dftaxon['genus'] == 'Acer')
      & (dftaxon['specificepithet'] == 'truncatum')
])
# Out:
#          taxonid       family genus specificepithet infraspecificepithet  \
# 18432    2891860  Sapindaceae  Acer       truncatum                 mono
# 73615    3003746  Sapindaceae  Acer       truncatum        quelpaertense
# 108648   2937799  Sapindaceae  Acer       truncatum          platanoides
# 114614   3003738  Sapindaceae  Acer       truncatum               mayrii
# 136391   3003748  Sapindaceae  Acer       truncatum              glaucum
# 213339   2937807  Sapindaceae  Acer       truncatum           barbinerve
# 422018   3226789  Sapindaceae  Acer       truncatum           barbinerve
# 431813   2937795  Sapindaceae  Acer       truncatum                paxii
# 838785   2616595  Sapindaceae  Acer       truncatum           barbinerve
# 923790   3226790  Sapindaceae  Acer       truncatum           barbinerve
# 954153   3005052  Sapindaceae  Acer       truncatum              pilosum
# 954154   2937798  Sapindaceae  Acer       truncatum                nudum
# 954155   3005053  Sapindaceae  Acer       truncatum       albovariegatum
# 954156   2616596  Sapindaceae  Acer       truncatum              beipiao
# 954157   2616597  Sapindaceae  Acer       truncatum             cordatum
# 1249341  2616594  Sapindaceae  Acer       truncatum                  NaN
#
#                               scientificname scientfiicnameauthorship  \
# 18432             Acer truncatum subsp. mono      (Maxim.) A.E.Murray
# 73615    Acer truncatum subsp. quelpaertense    (W.P.Fang) A.E.Murray
# 108648       Acer truncatum var. platanoides           (Miyabe) Nakai
# 114614          Acer truncatum subsp. mayrii     (Schwer.) A.E.Murray
# 136391             Acer truncatum f. glaucum      (Koidz.) A.E.Murray
# 213339        Acer truncatum var. barbinerve          (Nakai) T.B.Lee
# 422018          Acer truncatum f. barbinerve            (Nakai) M.Kim
# 431813             Acer truncatum var. paxii     (Schwer.) A.E.Murray
# 838785          Acer truncatum f. barbinerve                  Schwer.
# 923790        Acer truncatum var. barbinerve                    Nakai
# 954153           Acer truncatum var. pilosum                  Schwer.
# 954154             Acer truncatum var. nudum                  Schwer.
# 954155      Acer truncatum f. albovariegatum                  Schwer.
# 954156           Acer truncatum var. beipiao                 S.L.Tung
# 954157            Acer truncatum f. cordatum                 L.S.Tung
# 1249341                       Acer truncatum                    Bunge
#
#           taxonrank taxonomicstatus  acceptednameusageid  parentnameusageid  \
# 18432    Subspecies         Synonym            2616236.0                NaN
# 73615    Subspecies         Synonym            2616236.0                NaN
# 108648      Variety         Synonym            2616594.0                NaN
# 114614   Subspecies         Synonym            2616233.0                NaN
# 136391         Form         Synonym            2616228.0                NaN
# 213339      Variety    Illegitimate            2616594.0                NaN
# 422018         Form    Illegitimate            2616594.0                NaN
# 431813      Variety         Synonym            2616236.0                NaN
# 838785         Form         Synonym            3261540.0                NaN
# 923790      Variety    Illegitimate            2616594.0                NaN
# 954153      Variety         Synonym            2616594.0                NaN
# 954154      Variety         Synonym            2616594.0                NaN
# 954155         Form         Synonym            2616594.0                NaN
# 954156      Variety         Synonym            2616594.0                NaN
# 954157         Form         Synonym            2616594.0                NaN
# 1249341     Species        Accepted            2616594.0          2615354.0
#
#          originalnameusageid                            namepublishedin  \
# 18432              2615951.0                         Kalmia 1: 7 (1969)
# 73615              3003745.0                         Kalmia 1: 7 (1969)
# 108648             2615879.0                J. Jap. Bot. 18: 613 (1942)
# 114614             2615927.0                         Kalmia 1: 6 (1969)
# 136391             2616227.0                         Kalmia 1: 7 (1969)
# 213339             2937806.0           Ill. Woody Pl. Korea: 308 (1966)
# 422018             3226790.0             Korean Endemic Pl.: 547 (2017)
# 431813             2616238.0                        Kalmia 1: 17 (1969)
# 838785                   NaN  Mitt. Deutsch. Dendrol. Ges. 5: 81 (1896)
# 923790                   NaN        Handb. Kor.-Manch. For.: 163 (1939)
# 954153                   NaN  Mitt. Deutsch. Dendrol. Ges. 5: 81 (1896)
# 954154                   NaN  Mitt. Deutsch. Dendrol. Ges. 5: 81 (1896)
# 954155                   NaN  Mitt. Deutsch. Dendrol. Ges. 5: 81 (1896)
# 954156                   NaN   Bull. Bot. Res., Harbin 5(1): 105 (1985)
# 954157                   NaN   Bull. Bot. Res., Harbin 5(1): 105 (1985)
# 1249341                  NaN            Enum. Pl. China Bor.: 10 (1833)
#
#         nomenclaturalstatus                                     taxonremarks  \
# 18432                   NaN                                              NaN
# 73615                   NaN                                              NaN
# 108648                  NaN                                              NaN
# 114614                  NaN                                              NaN
# 136391                  NaN                                              NaN
# 213339        , nom. illeg.                                              NaN
# 422018        , nom. illeg.                                              NaN
# 431813                  NaN                                              NaN
# 838785                  NaN                                              NaN
# 923790        , nom. illeg.                                              NaN
# 954153                  NaN                                              NaN
# 954154                  NaN                                              NaN
# 954155                  NaN                                              NaN
# 954156                  NaN                                              NaN
# 954157                  NaN                                              NaN
# 1249341                 NaN  Russian Far East to N. & E. China, Korea, Japan
#
#         scientificnameid  \
# 18432    ipni:60470272-2
# 73615    ipni:60470274-2
# 108648               NaN
# 114614   ipni:60470271-2
# 136391   ipni:60470276-2
# 213339               NaN
# 422018   ipni:77175576-1
# 431813               NaN
# 838785               NaN
# 923790   ipni:77175575-1
# 954153               NaN
# 954154               NaN
# 954155               NaN
# 954156     ipni:918769-1
# 954157     ipni:918770-1
# 1249341    ipni:781552-1
#
#                                                                                                              dynamicproperties  \
# 18432              {"powoid":"60470272-2","lifeform":"","climate":"","homotypicsynonym":"T","hybridformula":"","reviewed":"N"}
# 73615               {"powoid":"60470274-2","lifeform":"","climate":"","homotypicsynonym":"","hybridformula":"","reviewed":"N"}
# 108648               {"powoid":"2937799-4","lifeform":"","climate":"","homotypicsynonym":"","hybridformula":"","reviewed":"N"}
# 114614             {"powoid":"60470271-2","lifeform":"","climate":"","homotypicsynonym":"T","hybridformula":"","reviewed":"N"}
# 136391             {"powoid":"60470276-2","lifeform":"","climate":"","homotypicsynonym":"T","hybridformula":"","reviewed":"N"}
# 213339               {"powoid":"2937807-4","lifeform":"","climate":"","homotypicsynonym":"","hybridformula":"","reviewed":"N"}
# 422018              {"powoid":"77175576-1","lifeform":"","climate":"","homotypicsynonym":"","hybridformula":"","reviewed":"N"}
# 431813               {"powoid":"2937795-4","lifeform":"","climate":"","homotypicsynonym":"","hybridformula":"","reviewed":"N"}
# 838785               {"powoid":"2616595-4","lifeform":"","climate":"","homotypicsynonym":"","hybridformula":"","reviewed":"N"}
# 923790              {"powoid":"77175575-1","lifeform":"","climate":"","homotypicsynonym":"","hybridformula":"","reviewed":"N"}
# 954153               {"powoid":"3005052-4","lifeform":"","climate":"","homotypicsynonym":"","hybridformula":"","reviewed":"N"}
# 954154               {"powoid":"2937798-4","lifeform":"","climate":"","homotypicsynonym":"","hybridformula":"","reviewed":"N"}
# 954155               {"powoid":"3005053-4","lifeform":"","climate":"","homotypicsynonym":"","hybridformula":"","reviewed":"N"}
# 954156   {"powoid":"918769-1","lifeform":"tree","climate":"temperate","homotypicsynonym":"","hybridformula":"","reviewed":"N"}
# 954157                {"powoid":"918770-1","lifeform":"","climate":"","homotypicsynonym":"","hybridformula":"","reviewed":"N"}
# 1249341  {"powoid":"781552-1","lifeform":"tree","climate":"temperate","homotypicsynonym":"","hybridformula":"","reviewed":"N"}
#
#                                                                     references
# 18432    https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:60470272-2
# 73615    https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:60470274-2
# 108648    https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:2937799-4
# 114614   https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:60470271-2
# 136391   https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:60470276-2
# 213339    https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:2937807-4
# 422018   https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:77175576-1
# 431813    https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:2937795-4
# 838785    https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:2616595-4
# 923790   https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:77175575-1
# 954153    https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:3005052-4
# 954154    https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:2937798-4
# 954155    https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:3005053-4
# 954156     https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:918769-1
# 954157     https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:918770-1
# 1249341    https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:781552-1
